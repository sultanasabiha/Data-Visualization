# %%
import pandas as pd  # data processing, CSV file I/O
dom = pd.read_csv("Domestic_Violence_Calls_from_2020_to_Present.csv")
cov = pd.read_csv("LA_County_COVID_Cases.csv")


from sklearn.preprocessing import MinMaxScaler
import plotly.express as px 
import cufflinks as cf
import plotly.graph_objects as go
from plotly.subplots import make_subplots
cf.go_offline()
# %matplotlib inline
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dom.info()
cov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62064 entries, 0 to 62063
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DR_NO           62064 non-null  int64
#  1   Date Rptd       62064 non-null  object
#  2   DATE OCC        62064 non-null  object
#  3   TIME OCC        62064 non-null  int64
#  4   AREA            62064 non-null  int64
#  5   AREA NAME       62064 non-null  object
#  6   Rpt Dist No     62064 non-null  int64
#  7   Part 1-2        62064 non-null  int64
#  8   Crm Cd          62064 non-null  int64
#  9   Crm Cd Desc     62064 non-null  object
#  10  Mocodes         62064 non-null  object
#  11  Vict Age        62064 non-null  int64
#  12  Vict Sex        62041 non-null  object
#  13  Vict Descent    62040 non-null  object
#  14  Premis Cd       62064 non-null  int64
#  15  Premis Desc     62062 non-null  object
#  16  Weapon Used Cd  56141 non-null  float64
#  17  Weapon Desc     56141 non-null  object
#  18  Status          62064 non-null  object
#  19  Status Desc     62064 non-null  object
#  20  Crm Cd 1        62064 non-null  int64
#  21  Crm Cd 2        5256 non-null   float64
#  22  Crm Cd 3        266 non-null    float64
#  23  Crm Cd 4        14 non-null     float64
#  24  LOCATION        62064 non-null  object
#  25  Cross Street    8116 non-null   object
#  26  LAT             62064 non-null  float64
#  27  LON             62064 non-null  float64
# dtypes: float64(6), int64(9), object(13)
# memory usage: 13.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16729 entries, 0 to 16728
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   county            16729 non-null  object
#  1   state             16729 non-null  object
#  2   fips              16729 non-null  int64
#  3   date              16729 non-null  object
#  4   Lat               16729 non-null  float64
#  5   Lon               16729 non-null  float64
#  6   cases             16729 non-null  int64
#  7   deaths            16729 non-null  int64
#  8   people_tested     0 non-null      float64
#  9   state_cases       16729 non-null  int64
#  10  state_deaths      16729 non-null  int64
#  11  new_cases         16729 non-null  int64
#  12  new_deaths        16729 non-null  int64
#  13  new_state_cases   16729 non-null  int64
#  14  new_state_deaths  16729 non-null  int64
# dtypes: float64(3), int64(9), object(3)
# memory usage: 1.9+ MB

# %%
df=dom.loc[:,['DATE OCC','Crm Cd','Crm Cd Desc','Mocodes','Vict Sex','Vict Descent','Premis Cd','Premis Desc']]

df.loc['DATE OCC']=dom.loc[dom['DATE OCC'].str.contains('2020' , regex=True), 'DATE OCC'] = '2020'
df.loc['DATE OCC']=dom.loc[dom['DATE OCC'].str.contains('2021' , regex=True), 'DATE OCC'] = '2021'
df.loc['DATE OCC']=dom.loc[dom['DATE OCC'].str.contains('2022' , regex=True), 'DATE OCC'] = '2022'
df.loc['DATE OCC']=dom.loc[dom['DATE OCC'].str.contains('2023' , regex=True), 'DATE OCC'] = '2023'

# %%
df['DATE OCC']
# Out:
# 0           2020
# 1           2020
# 2           2020
# 3           2020
# 4           2020
#             ...
# 62060       2023
# 62061       2023
# 62062       2023
# 62063       2023
# DATE OCC    2023
# Name: DATE OCC, Length: 62065, dtype: object

# %%
dv=[236,250,251,761,926,626,627,647,763,928,930]
for x in df.index:
    if df.loc[x,'Crm Cd'] in dv:
        df.loc[x,'DV']='Yes'
    else:
        df.loc[x,'DV']='No'

# %% [markdown]
# #Question 1

# %%
g1=df[df['DV']=='Yes']
g1=g1.groupby(['DATE OCC','Crm Cd Desc','Vict Sex']).size().to_frame(name="Count").reset_index()
fig = px.line(g1, x='Crm Cd Desc', y='Count', color='Vict Sex',animation_frame="DATE OCC",labels={'DATE OCC':'Year'}, animation_group="Count",title="Cases of Domestic Violation")
fig['layout']['sliders'][0]['pad']=dict(l=10,r= 10, t= 150)
fig.update_layout(hovermode="x unified")
fig.show()

g2=df[df['DV']=='No']
g2=g2.groupby(['DATE OCC','Crm Cd Desc','Vict Sex']).size().to_frame(name="Count").reset_index()

fig = px.line(g2, x='Crm Cd Desc', y='Count', color='Vict Sex',animation_frame="DATE OCC", labels={'DATE OCC':'Year'},animation_group="Count",title="Other Cases")
fig['layout']['sliders'][0]['pad']=dict(l=10,r= 10, t= 250)
fig.update_layout(hovermode="x unified")
fig.show()
# Out:
# <div>                            <div id="04de6e8f-780d-4aac-aba1-c863871d9a16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04de6e8f-780d-4aac-aba1-c863871d9a16")) {                    Plotly.newPlot(                        "04de6e8f-780d-4aac-aba1-c863871d9a16",                        [{"hovertemplate":"Vict Sex=F\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[243,4,465,2151,7792,35,14,3],"legendgroup":"F","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"F","orientation":"v","showlegend":true,"x":["BRANDISH WEAPON","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT","CRIMINAL THREATS - NO WEAPON DISPLAYED","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","STALKING","THREATENING PHONE CALLS\u002fLETTERS","THROWING OBJECT AT MOVING VEHICLE"],"xaxis":"x","y":[243,4,465,2151,7792,35,14,3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Vict Sex=M\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[83,3,56,669,2573,1,3,1],"legendgroup":"M","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"M","orientation":"v","showlegend":true,"x":["BRANDISH WEAPON","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT","CRIMINAL THREATS - NO WEAPON DISPLAYED","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","SHOTS FIRED AT INHABITED DWELLING","STALKING","THREATENING PHONE CALLS\u002fLETTERS"],"xaxis":"x","y":[83,3,56,669,2573,1,3,1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Vict Sex=X\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[1,3,16],"legendgroup":"X","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"X","orientation":"v","showlegend":true,"x":["CRIMINAL THREATS - NO WEAPON DISPLAYED","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT"],"xaxis":"x","y":[1,3,16],"yaxis":"y","type":"scatter"},{"hovertemplate":"Vict Sex=H\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[1],"legendgroup":"H","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"H","orientation":"v","showlegend":true,"x":["INTIMATE PARTNER - SIMPLE ASSAULT"],"xaxis":"x","y":[1],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdc ...
# <div>                            <div id="a6b7cad0-4068-42a7-b851-1e7cbe3925cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6b7cad0-4068-42a7-b851-1e7cbe3925cc")) {                    Plotly.newPlot(                        "a6b7cad0-4068-42a7-b851-1e7cbe3925cc",                        [{"hovertemplate":"Vict Sex=F\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[5,128,25,102,1,21,38,2,2,2,1,1,6,56,1,8,3,7,18,2,1,25,2,78,1,15,8,21,1,3,11,146,285,24,19,1,15,3,3,1,2,2,120,149,38,15,3,171,182,2,160,457,29],"legendgroup":"F","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"F","orientation":"v","showlegend":true,"x":["ARSON","ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BATTERY POLICE (SIMPLE)","BATTERY WITH SEXUAL CONTACT","BURGLARY","BURGLARY FROM VEHICLE","BURGLARY, ATTEMPTED","CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT","CHILD ANNOYING (17YRS & UNDER)","CHILD NEGLECT (SEE 300 W.I.C.)","CHILD STEALING","CONTEMPT OF COURT","CONTRIBUTING","CRIMINAL HOMICIDE","DISTURBING THE PEACE","EXTORTION","FALSE IMPRISONMENT","HUMAN TRAFFICKING - COMMERCIAL SEX ACTS","HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE","KIDNAPPING","KIDNAPPING - GRAND ATTEMPT","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","LEWD\u002fLASCIVIOUS ACTS WITH CHILD","ORAL COPULATION","OTHER ASSAULT","OTHER MISCELLANEOUS CRIME","PEEPING TOM","PURSE SNATCHING","RAPE, ATTEMPTED","RAPE, FORCIBLE","ROBBERY","SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W\u002f FRGN OBJ","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SHOPLIFTING - PETTY THEFT ($950 & UNDER)","SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH","THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)","THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)","THEFT FROM PERSON - ATTEMPT","THEFT OF IDENTITY","THEFT PLAIN - ATTEMPT","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT, PERSON","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","TRESPASSING","UNAUTHORIZED COMPUTER ACCESS","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VANDALISM - MISDEAMEANOR ($399 OR UNDER)","VEHICLE - STOLEN","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER","VIOLATION OF TEMPORARY RESTRAINING ORDER"],"xaxis":"x","y":[5,128,25,102,1,21,38,2,2,2,1,1,6,56,1,8,3,7,18,2,1,25,2,78,1,15,8,21,1,3,11,146,285,24,19,1,15,3,3,1,2,2,120,149,38,15,3,171,182,2,160,457,29],"yaxis":"y","type":"scatter"},{"hovertemplate":"Vict Sex=M\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[3,90,5,38,1,7,2,2,1,6,14,4,1,1,3,15,2,5,4,3,31,1,2,3,2,2,2,1,28,11,13,7,74,48,51,66,4],"legendgroup":"M","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"M","orientation":"v","showlegend":true,"x":["ARSON","ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BATTERY WITH SEXUAL CONTACT","BURGLARY","BURGLARY FROM VEHICLE","BURGLARY, ATTEMPTED","CHILD NEGLECT (SEE 300 W.I.C.)","CHILD STEALING","CONTEMPT OF COURT","CRIMINAL HOMICIDE","DOCUMENT FORGERY \u002f STOLEN FELONY","EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)","FALSE IMPRISONMENT","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ORAL COPULATION","OTHER ASSAULT","OTHER MISCELLANEOUS CRIME","RAPE, FORCIBLE","ROBBERY","SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W\u002f FRGN OBJ","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH","THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)","THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)","THEFT FROM PERSON - ATTEMPT","THEFT OF IDENTITY", ...

# %%
fig = px.line(g1, x='DATE OCC', y='Count', facet_col='Crm Cd Desc',
             facet_col_wrap=2, labels={'DATE OCC':'Year'}, title='Domestic Violence Over the years')
fig.update_layout(hovermode="x unified")
fig.show()
# Out:
# <div>                            <div id="1881d261-398f-456d-ae6b-666c98bf81c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1881d261-398f-456d-ae6b-666c98bf81c9")) {                    Plotly.newPlot(                        "1881d261-398f-456d-ae6b-666c98bf81c9",                        [{"hovertemplate":"Crm Cd Desc=BRANDISH WEAPON\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020","2020","2021","2021","2022","2022","2023","2023"],"xaxis":"x9","y":[243,83,222,90,236,83,119,34],"yaxis":"y9","type":"scatter"},{"hovertemplate":"Crm Cd Desc=CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020","2020","2021","2021","2022","2022","2023","2023"],"xaxis":"x10","y":[4,3,3,1,4,2,2,2],"yaxis":"y10","type":"scatter"},{"hovertemplate":"Crm Cd Desc=CRIMINAL THREATS - NO WEAPON DISPLAYED\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020","2020","2020","2021","2021","2022","2022","2023","2023"],"xaxis":"x7","y":[465,56,1,484,68,537,66,307,28],"yaxis":"y7","type":"scatter"},{"hovertemplate":"Crm Cd Desc=INTIMATE PARTNER - AGGRAVATED ASSAULT\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020","2020","2020","2021","2021","2021","2022","2022","2022","2022","2023","2023","2023","2023"],"xaxis":"x8","y":[2151,669,3,2362,650,3,2218,1,622,3,1318,1,385,1],"yaxis":"y8","type":"scatter"},{"hovertemplate":"Crm Cd Desc=INTIMATE PARTNER - SIMPLE ASSAULT\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020","2020","2020","2020","2021","2021","2021","2021","2022","2022","2022","2022","2023","2023","2023"],"xaxis":"x5","y":[7792,1,2573,16,7821,1,2438,11,8248,1,2493,19,4619,1465,12],"yaxis":"y5","type":"scatter"},{"hovertemplate":"Crm Cd Desc=SHOTS FIRED AT INHABITED DWELLING\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020","2021","2022","2023","2023"],"xaxis":"x6","y":[1,4,1,3,1],"yaxis":"y6","type":"scatter"},{"hovertemplate":"Crm Cd Desc=STALKING\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020","2020","2021","2021","2022","2022","2023","2023"],"xaxis":"x3","y":[35,3,60,6,47,4,21,1],"yaxis":"y3","type":"scatter"},{"hovertemplate":"Crm Cd Desc=THREATENING PHONE CALLS\u002fLETTERS\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[ ...

# %% [markdown]
# #Question 2

# %%
g3=df.loc[df['Premis Cd']==501 ]
g3 = g3[g3['Mocodes'].str.contains('1814')]

print(g3)
# Out:
#       DATE OCC Crm Cd                                     Crm Cd Desc  \
# 0         2020    626               INTIMATE PARTNER - SIMPLE ASSAULT
# 1         2020    626               INTIMATE PARTNER - SIMPLE ASSAULT
# 6         2020    236           INTIMATE PARTNER - AGGRAVATED ASSAULT
# 11        2020    210                                         ROBBERY
# 21        2020    901                  VIOLATION OF RESTRAINING ORDER
# ...        ...    ...                                             ...
# 62027     2023    626               INTIMATE PARTNER - SIMPLE ASSAULT
# 62031     2023    626               INTIMATE PARTNER - SIMPLE ASSAULT
# 62032     2023    230  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 62035     2023    956         LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# 62057     2023    626               INTIMATE PARTNER - SIMPLE ASSAULT
#
#                                             Mocodes Vict Sex Vict Descent  \
# 0                                    2000 1814 0416        F            H
# 1                               0400 0416 1814 2000        F            H
# 6      0416 0446 0408 2000 1814 0913 0216 1309 0329        F            W
# 11                              0913 1814 0448 2000        F            H
# 21                              0913 2038 2000 1814        M            B
# ...                                             ...      ...          ...
# 62027                                0416 2000 1814        F            B
# 62031       0913 0416 0446 1402 2002 2001 1814 2000        F            B
# 62032       2000 0432 0344 0345 0913 1402 1814 2004        M            H
# 62035                           0913 2000 1814 1912        F            W
# 62057                 2000 0913 1814 0416 0444 1300        F            O
#
#       Premis Cd             Premis Desc   DV
# 0           501  SINGLE FAMILY DWELLING  Yes
# 1           501  SINGLE FAMILY DWELLING  Yes
# 6           501  SINGLE FAMILY DWELLING  Yes
# 11          501  SINGLE FAMILY DWELLING   No
# 21          501  SINGLE FAMILY DWELLING   No
# ...         ...                     ...  ...
# 62027       501  SINGLE FAMILY DWELLING  Yes
# 62031       501  SINGLE FAMILY DWELLING  Yes
# 62032       501  SINGLE FAMILY DWELLING   No
# 62035       501  SINGLE FAMILY DWELLING   No
# 62057       501  SINGLE FAMILY DWELLING  Yes
#
# [10639 rows x 9 columns]

# %%
g3=df.loc[df['Premis Cd']==501 ]
g3 = g3[g3['Mocodes'].str.contains('1814')]
g3=g3.groupby(['DATE OCC','Crm Cd Desc','Vict Sex']).size().to_frame(name="Count").reset_index()
fig = px.bar(g3, x='Crm Cd Desc', y='Count', color='Vict Sex',animation_frame="DATE OCC",labels={'DATE OCC':'Year'}, animation_group="Count",title="Single Family Dwelling Cases with Boyfriend/Girlfriend as Prime Suspect")
fig['layout']['sliders'][0]['pad']=dict(l=10,r= 10, t= 250)
fig.update_layout(hovermode="x unified")
fig.show()
# Out:
# <div>                            <div id="e3f3b21b-c06b-479a-92c6-2369560e6154" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3f3b21b-c06b-479a-92c6-2369560e6154")) {                    Plotly.newPlot(                        "e3f3b21b-c06b-479a-92c6-2369560e6154",                        [{"alignmentgroup":"True","hovertemplate":"Vict Sex=F\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[1,19,7,10,5,43,12,1,2,10,105,1,4,392,1200,1,31,2,8,1,2,37,39,4,2,2,7,1,1,19,22,7,3,4,17,23,25,97,9],"legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"textposition":"auto","x":["ARSON","ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BATTERY WITH SEXUAL CONTACT","BRANDISH WEAPON","BURGLARY","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT","CHILD STEALING","CONTEMPT OF COURT","CRIMINAL THREATS - NO WEAPON DISPLAYED","EXTORTION","FALSE IMPRISONMENT","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","KIDNAPPING","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ORAL COPULATION","OTHER MISCELLANEOUS CRIME","PEEPING TOM","RAPE, ATTEMPTED","RAPE, FORCIBLE","ROBBERY","SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W\u002f FRGN OBJ","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH","STALKING","THEFT OF IDENTITY","THEFT PLAIN - ATTEMPT","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT, PERSON","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","THREATENING PHONE CALLS\u002fLETTERS","TRESPASSING","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VANDALISM - MISDEAMEANOR ($399 OR UNDER)","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER","VIOLATION OF TEMPORARY RESTRAINING ORDER"],"xaxis":"x","y":[1,19,7,10,5,43,12,1,2,10,105,1,4,392,1200,1,31,2,8,1,2,37,39,4,2,2,7,1,1,19,22,7,3,4,17,23,25,97,9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=M\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[11,4,16,2,1,3,2,11,1,114,411,5,1,5,2,1,2,1,1,4,2,2,1,2,6,9,7,8,1],"legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","BATTERY - SIMPLE ASSAULT","BRANDISH WEAPON","BURGLARY","BURGLARY, ATTEMPTED","CHILD STEALING","CONTEMPT OF COURT","CRIMINAL THREATS - NO WEAPON DISPLAYED","FALSE IMPRISONMENT","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ORAL COPULATION","ROBBERY","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SHOTS FIRED AT INHABITED DWELLING","SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH","STALKING","THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT, PERSON","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","THREATENING PHONE CALLS\u002fLETTERS","TRESPASSING","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VANDALISM - MISDEAMEANOR ($399 OR UNDER)","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER","VIOLATION OF TEMPORARY RESTRAINING ORDER"],"xaxis":"x","y":[11,4,16,2,1,3,2,11,1,114,411,5,1,5,2,1,2,1,1,4,2,2,1,2,6,9,7,8,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444 ...

# %%
g3=df.loc[df['Premis Cd']==501 ]
g3 = g3[g3['Mocodes'].str.contains('1814')]
g3=g3.groupby(['DATE OCC','Crm Cd Desc','Vict Descent']).size().to_frame(name="Count").reset_index()
fig = px.bar(g3, x='Crm Cd Desc', y='Count', color='Vict Descent',animation_frame="DATE OCC",labels={'DATE OCC':'Year'}, animation_group="Count",title="Single Family Dwelling Cases with Boyfriend/Girlfriend as Prime Suspect with respect to ethnicity")
fig['layout']['sliders'][0]['pad']=dict(l=10,r= 10, t= 250)
fig.update_layout(hovermode="x unified")
fig.show()
# Out:
# <div>                            <div id="6c113bb1-a667-4719-9d94-a7f0e209f2cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c113bb1-a667-4719-9d94-a7f0e209f2cb")) {                    Plotly.newPlot(                        "6c113bb1-a667-4719-9d94-a7f0e209f2cb",                        [{"alignmentgroup":"True","hovertemplate":"Vict Descent=B\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[1,7,1,4,26,5,2,5,48,1,178,401,1,7,1,4,1,8,14,1,1,1,2,1,9,14,6,3,4,13,13,7,24,3],"legendgroup":"B","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"v","showlegend":true,"textposition":"auto","x":["ARSON","ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BRANDISH WEAPON","BURGLARY","CHILD STEALING","CONTEMPT OF COURT","CRIMINAL THREATS - NO WEAPON DISPLAYED","FALSE IMPRISONMENT","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","KIDNAPPING","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ORAL COPULATION","OTHER MISCELLANEOUS CRIME","PEEPING TOM","RAPE, FORCIBLE","ROBBERY","SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W\u002f FRGN OBJ","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SHOTS FIRED AT INHABITED DWELLING","STALKING","THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT, PERSON","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","THREATENING PHONE CALLS\u002fLETTERS","TRESPASSING","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VANDALISM - MISDEAMEANOR ($399 OR UNDER)","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER","VIOLATION OF TEMPORARY RESTRAINING ORDER"],"xaxis":"x","y":[1,7,1,4,26,5,2,5,48,1,178,401,1,7,1,4,1,8,14,1,1,1,2,1,9,14,6,3,4,13,13,7,24,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Descent=H\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[16,5,6,4,24,8,1,1,2,6,61,2,232,887,18,1,4,1,18,25,3,2,4,5,1,12,9,2,2,13,14,61,3],"legendgroup":"H","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"H","offsetgroup":"H","orientation":"v","showlegend":true,"textposition":"auto","x":["ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BATTERY WITH SEXUAL CONTACT","BRANDISH WEAPON","BURGLARY","BURGLARY, ATTEMPTED","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT","CHILD STEALING","CONTEMPT OF COURT","CRIMINAL THREATS - NO WEAPON DISPLAYED","FALSE IMPRISONMENT","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ORAL COPULATION","OTHER MISCELLANEOUS CRIME","RAPE, ATTEMPTED","RAPE, FORCIBLE","ROBBERY","SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W\u002f FRGN OBJ","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH","STALKING","THEFT PLAIN - ATTEMPT","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT, PERSON","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VANDALISM - MISDEAMEANOR ($399 OR UNDER)","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER","VIOLATION OF TEMPORARY RESTRAINING ORDER"],"xaxis":"x","y":[16,5,6,4,24,8,1,1,2,6,61,2,232,887,18,1,4,1,18,25,3,2,4,5,1,12,9,2,2,13,14,61,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Descent=W\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[7,1,2,1,7,1,1,6,2,76,242,8,1,10,4,1,1,2,2,7,5,10,16,3],"legendgroup":"W","marker":{"color":"#00cc96","pattern":{" ...

# %%
g4=df.loc[df['Premis Cd']==502]
g4=g4[g4['Mocodes'].str.contains('1814')]
g4=g4.groupby(['DATE OCC','Crm Cd Desc','Vict Sex']).size().to_frame(name="Count").reset_index()
fig = px.bar(g4, x='Crm Cd Desc', y='Count', color='Vict Sex',labels={'DATE OCC':'Year'},animation_frame="DATE OCC", animation_group="Count",title="Multi-Unit Family Dwelling Cases with Boyfriend/Girlfriend as Prime Suspect")
fig['layout']['sliders'][0]['pad']=dict(l=10,r= 10, t= 250)
fig.update_layout(hovermode="x unified")
fig.show()
# Out:
# <div>                            <div id="dc4db229-f2ca-4072-b923-0b5f9ecc6e64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc4db229-f2ca-4072-b923-0b5f9ecc6e64")) {                    Plotly.newPlot(                        "dc4db229-f2ca-4072-b923-0b5f9ecc6e64",                        [{"alignmentgroup":"True","hovertemplate":"Vict Sex=F\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[12,1,8,2,31,16,2,1,7,1,1,77,1,5,384,1141,1,1,18,2,2,1,2,33,44,12,3,1,5,9,1,1,23,23,7,4,4,2,23,35,22,66,2],"legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"textposition":"auto","x":["ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BATTERY WITH SEXUAL CONTACT","BRANDISH WEAPON","BURGLARY","BURGLARY, ATTEMPTED","CHILD ANNOYING (17YRS & UNDER)","CONTEMPT OF COURT","CONTRIBUTING","CRIMINAL HOMICIDE","CRIMINAL THREATS - NO WEAPON DISPLAYED","DISTURBING THE PEACE","FALSE IMPRISONMENT","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","KIDNAPPING","KIDNAPPING - GRAND ATTEMPT","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ORAL COPULATION","OTHER ASSAULT","OTHER MISCELLANEOUS CRIME","RAPE, ATTEMPTED","RAPE, FORCIBLE","ROBBERY","SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W\u002f FRGN OBJ","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SHOPLIFTING - PETTY THEFT ($950 & UNDER)","SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH","STALKING","THEFT FROM PERSON - ATTEMPT","THEFT OF IDENTITY","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT, PERSON","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","THREATENING PHONE CALLS\u002fLETTERS","TRESPASSING","UNAUTHORIZED COMPUTER ACCESS","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VANDALISM - MISDEAMEANOR ($399 OR UNDER)","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER","VIOLATION OF TEMPORARY RESTRAINING ORDER"],"xaxis":"x","y":[12,1,8,2,31,16,2,1,7,1,1,77,1,5,384,1141,1,1,18,2,2,1,2,33,44,12,3,1,5,9,1,1,23,23,7,4,4,2,23,35,22,66,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=M\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[5,1,1,19,1,1,2,1,10,100,418,3,3,1,1,13,5,1,10,6,7,3],"legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BRANDISH WEAPON","BURGLARY","BURGLARY, ATTEMPTED","CHILD STEALING","CONTEMPT OF COURT","CRIMINAL THREATS - NO WEAPON DISPLAYED","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ROBBERY","SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W\u002f FRGN OBJ","THEFT OF IDENTITY","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","TRESPASSING","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VANDALISM - MISDEAMEANOR ($399 OR UNDER)","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER"],"xaxis":"x","y":[5,1,1,19,1,1,2,1,10,100,418,3,3,1,1,13,5,1,10,6,7,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=X\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[1,1,1],"legendgroup":"X","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"X","offsetgroup":"X","orientation":"v","showlegend":true,"textposition":"auto","x":["CRIMINAL THREATS - NO WEAPON DI ...

# %%
g4=df.loc[df['Premis Cd']==502] 
g4=g4[g4['Mocodes'].str.contains('1814',regex=True)]
g4=g4.groupby(['DATE OCC','Crm Cd Desc','Vict Sex']).size().to_frame(name="Count").reset_index()
fig = px.line(g4, x='Crm Cd Desc', y='Count', color='Vict Sex',animation_frame="DATE OCC",labels={'DATE OCC':'Year'}, animation_group="Count",title="Multi-Unit Family Dwelling Cases with Boyfriend/Girlfriend as Prime Suspect")
fig['layout']['sliders'][0]['pad']=dict(l=10,r= 10, t= 250)
fig.update_layout(hovermode="x unified")
fig.show()
# Out:
# <div>                            <div id="b2d00480-9bcc-4181-9a95-ddc3b40c3563" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2d00480-9bcc-4181-9a95-ddc3b40c3563")) {                    Plotly.newPlot(                        "b2d00480-9bcc-4181-9a95-ddc3b40c3563",                        [{"hovertemplate":"Vict Sex=F\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[12,1,8,2,31,16,2,1,7,1,1,77,1,5,384,1141,1,1,18,2,2,1,2,33,44,12,3,1,5,9,1,1,23,23,7,4,4,2,23,35,22,66,2],"legendgroup":"F","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"F","orientation":"v","showlegend":true,"x":["ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BATTERY WITH SEXUAL CONTACT","BRANDISH WEAPON","BURGLARY","BURGLARY, ATTEMPTED","CHILD ANNOYING (17YRS & UNDER)","CONTEMPT OF COURT","CONTRIBUTING","CRIMINAL HOMICIDE","CRIMINAL THREATS - NO WEAPON DISPLAYED","DISTURBING THE PEACE","FALSE IMPRISONMENT","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","KIDNAPPING","KIDNAPPING - GRAND ATTEMPT","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ORAL COPULATION","OTHER ASSAULT","OTHER MISCELLANEOUS CRIME","RAPE, ATTEMPTED","RAPE, FORCIBLE","ROBBERY","SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W\u002f FRGN OBJ","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SHOPLIFTING - PETTY THEFT ($950 & UNDER)","SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH","STALKING","THEFT FROM PERSON - ATTEMPT","THEFT OF IDENTITY","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT, PERSON","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","THREATENING PHONE CALLS\u002fLETTERS","TRESPASSING","UNAUTHORIZED COMPUTER ACCESS","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VANDALISM - MISDEAMEANOR ($399 OR UNDER)","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER","VIOLATION OF TEMPORARY RESTRAINING ORDER"],"xaxis":"x","y":[12,1,8,2,31,16,2,1,7,1,1,77,1,5,384,1141,1,1,18,2,2,1,2,33,44,12,3,1,5,9,1,1,23,23,7,4,4,2,23,35,22,66,2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Vict Sex=M\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[5,1,1,19,1,1,2,1,10,100,418,3,3,1,1,13,5,1,10,6,7,3],"legendgroup":"M","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"M","orientation":"v","showlegend":true,"x":["ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BRANDISH WEAPON","BURGLARY","BURGLARY, ATTEMPTED","CHILD STEALING","CONTEMPT OF COURT","CRIMINAL THREATS - NO WEAPON DISPLAYED","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ROBBERY","SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W\u002f FRGN OBJ","THEFT OF IDENTITY","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","TRESPASSING","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VANDALISM - MISDEAMEANOR ($399 OR UNDER)","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER"],"xaxis":"x","y":[5,1,1,19,1,1,2,1,10,100,418,3,3,1,1,13,5,1,10,6,7,3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Vict Sex=X\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[1,1,1],"legendgroup":"X","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"X","orientation":"v","showlegend":true,"x":["CRIMINAL THREATS - NO WEAPON DISPLAYED","INTIMATE PARTNER - SIMPLE ASSAULT","VANDALISM - MISDEAMEANOR ($399 OR UN ...

# %%
g4=df.loc[df['Premis Cd']==101]
g4=g4[g4['Mocodes'].str.contains('1814',regex=True)]
g4=g4.groupby(['DATE OCC','Crm Cd Desc','Vict Sex']).size().to_frame(name="Count").reset_index()
fig = px.line(g4, x='Crm Cd Desc', y='Count', color='Vict Sex',labels={'DATE OCC':'Year'},animation_frame="DATE OCC", animation_group="Count",title="Street Cases with Boyfriend/Girlfriend as Prime Suspect")
fig['layout']['sliders'][0]['pad']=dict(l=10,r= 10, t= 250)
fig.update_layout(hovermode="x unified")
fig.show()
# Out:
# <div>                            <div id="e06007bd-2700-4698-b37f-99cecea5e4f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e06007bd-2700-4698-b37f-99cecea5e4f8")) {                    Plotly.newPlot(                        "e06007bd-2700-4698-b37f-99cecea5e4f8",                        [{"hovertemplate":"Vict Sex=M\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[1,16,1,2,8,1,5,69,159,1,6,1,1,2,2,1,5,1,2],"legendgroup":"M","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"M","orientation":"v","showlegend":true,"x":["ARSON","ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BRANDISH WEAPON","BURGLARY FROM VEHICLE","CRIMINAL THREATS - NO WEAPON DISPLAYED","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ROBBERY","THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)","THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT, PERSON","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER"],"xaxis":"x","y":[1,16,1,2,8,1,5,69,159,1,6,1,1,2,2,1,5,1,2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Vict Sex=F\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[13,1,4,26,1,1,1,3,1,34,1,1,1,215,657,8,2,1,2,7,49,6,1,1,16,20,3,1,1,11,12,2,9,27],"legendgroup":"F","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"F","orientation":"v","showlegend":true,"x":["ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","ATTEMPTED ROBBERY","BATTERY - SIMPLE ASSAULT","BRANDISH WEAPON","BURGLARY FROM VEHICLE","CHILD NEGLECT (SEE 300 W.I.C.)","CHILD STEALING","CONTEMPT OF COURT","CRIMINAL HOMICIDE","CRIMINAL THREATS - NO WEAPON DISPLAYED","EXTORTION","FALSE IMPRISONMENT","HUMAN TRAFFICKING - COMMERCIAL SEX ACTS","INTIMATE PARTNER - AGGRAVATED ASSAULT","INTIMATE PARTNER - SIMPLE ASSAULT","KIDNAPPING","LETTERS, LEWD  -  TELEPHONE CALLS, LEWD","ORAL COPULATION","PURSE SNATCHING","RAPE, FORCIBLE","ROBBERY","STALKING","THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)","THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)","THEFT PLAIN - PETTY ($950 & UNDER)","THEFT, PERSON","THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD","THREATENING PHONE CALLS\u002fLETTERS","THROWING OBJECT AT MOVING VEHICLE","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","VANDALISM - MISDEAMEANOR ($399 OR UNDER)","VEHICLE - STOLEN","VIOLATION OF COURT ORDER","VIOLATION OF RESTRAINING ORDER"],"xaxis":"x","y":[13,1,4,26,1,1,1,3,1,34,1,1,1,215,657,8,2,1,2,7,49,6,1,1,16,20,3,1,1,11,12,2,9,27],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3 ...

# %%
g4=df[df['Mocodes'].str.contains('1903',regex=True)]
g4=g4.groupby(['DATE OCC','Crm Cd Desc','Vict Sex']).size().to_frame(name="Count").reset_index()
fig = px.line(g4, x='Crm Cd Desc', y='Count', color='Vict Sex',labels={'DATE OCC':'Year'},animation_frame="DATE OCC", animation_group="Count",title="Crimes which involved CyberStalking")
fig.show()
# Out:
# <div>                            <div id="56f849a2-ed61-4521-9027-0032713083f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56f849a2-ed61-4521-9027-0032713083f3")) {                    Plotly.newPlot(                        "56f849a2-ed61-4521-9027-0032713083f3",                        [{"hovertemplate":"Vict Sex=F\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[1],"legendgroup":"F","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"F","orientation":"v","showlegend":true,"x":["CRIMINAL THREATS - NO WEAPON DISPLAYED"],"xaxis":"x","y":[1],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %%
g=df.loc[(df['Crm Cd']==121) | (df['Crm Cd']==122) | (df['Crm Cd']==815) | (df['Crm Cd']==820) | (df['Crm Cd']==821)]
print(g)
# Out:
#       DATE OCC Crm Cd                                        Crm Cd Desc  \
# 35        2020    121                                     RAPE, FORCIBLE
# 271       2020    121                                     RAPE, FORCIBLE
# 425       2020    121                                     RAPE, FORCIBLE
# 578       2020    121                                     RAPE, FORCIBLE
# 599       2020    121                                     RAPE, FORCIBLE
# ...        ...    ...                                                ...
# 61682     2023    815                SEXUAL PENETRATION W/FOREIGN OBJECT
# 61744     2023    821  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...
# 61772     2023    121                                     RAPE, FORCIBLE
# 61885     2023    121                                     RAPE, FORCIBLE
# 61954     2023    820                                    ORAL COPULATION
#
#                                                  Mocodes Vict Sex  \
# 35                         1415 1402 2000 0913 1814 0527        F
# 271         0913 0537 2038 0416 0507 0527 1309 1814 2000        F
# 425                        2000 1206 2002 0913 1814 0527        F
# 578                   1814 1817 1206 1262 0527 0913 2000        F
# 599         1813 2004 1218 2060 0500 1402 1415 0913 2000        F
# ...                                                  ...      ...
# 61682                      2000 0400 0913 1814 0515 1218        F
# 61744            0913 2000 0527 0536 0537 0381 1814 0519        F
# 61772                      1206 0907 2000 0400 0416 1814        F
# 61885  2000 1820 0913 2060 1218 0448 0537 0515 2004 0381        F
# 61954                 0512 2033 2000 1814 1309 0913 0507        F
#
#       Vict Descent Premis Cd                                   Premis Desc  DV
# 35               B       501                        SINGLE FAMILY DWELLING  No
# 271              B       502  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)  No
# 425              W       502  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)  No
# 578              H       108                                   PARKING LOT  No
# 599              O       158                          TRANSIENT ENCAMPMENT  No
# ...            ...       ...                                           ...  ..
# 61682            B       101                                        STREET  No
# 61744            O       502  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)  No
# 61772            H       502  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)  No
# 61885            W       102                                      SIDEWALK  No
# 61954            B       101                                        STREET  No
#
# [771 rows x 9 columns]

# %%
g=df.loc[(df['Crm Cd']==121) | (df['Crm Cd']==122) | (df['Crm Cd']==815) | (df['Crm Cd']==820) | (df['Crm Cd']==821)]
g5=g.groupby(['DATE OCC','Crm Cd Desc']).size().to_frame(name="Count").reset_index()
fig = px.line(g5, x='DATE OCC', y='Count', color='Crm Cd Desc',labels={'DATE OCC':'Year'},title="Violent Crimes : Rape")
fig.show()
# Out:
# <div>                            <div id="29c9ef1d-1cdd-40e2-8888-8ea8046d2262" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29c9ef1d-1cdd-40e2-8888-8ea8046d2262")) {                    Plotly.newPlot(                        "29c9ef1d-1cdd-40e2-8888-8ea8046d2262",                        [{"hovertemplate":"Crm Cd Desc=ORAL COPULATION\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ORAL COPULATION","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ORAL COPULATION","orientation":"v","showlegend":true,"x":["2020","2021","2022","2023"],"xaxis":"x","y":[17,15,24,8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crm Cd Desc=RAPE, ATTEMPTED\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RAPE, ATTEMPTED","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RAPE, ATTEMPTED","orientation":"v","showlegend":true,"x":["2020","2021","2022","2023"],"xaxis":"x","y":[11,9,15,5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crm Cd Desc=RAPE, FORCIBLE\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RAPE, FORCIBLE","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RAPE, FORCIBLE","orientation":"v","showlegend":true,"x":["2020","2021","2022","2023"],"xaxis":"x","y":[149,151,160,57],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crm Cd Desc=SEXUAL PENETRATION W\u002fFOREIGN OBJECT\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SEXUAL PENETRATION W\u002fFOREIGN OBJECT","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"SEXUAL PENETRATION W\u002fFOREIGN OBJECT","orientation":"v","showlegend":true,"x":["2020","2021","2022","2023"],"xaxis":"x","y":[21,26,30,15],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crm Cd Desc=SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH","orientation":"v","showlegend":true,"x":["2020","2021","2022","2023"],"xaxis":"x","y":[18,16,17,7],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888 ...

# %%
for x in g.index:
    if '1814' in g.loc[x,'Mocodes']:
        g.loc[x,'Suspect']='Boyfriend'
    elif '1813' in g.loc[x,'Mocodes']:
        g.loc[x,'Suspect']='Spouse'
    elif '1812' in g.loc[x,'Mocodes']:
        g.loc[x,'Suspect']='Foster-Parent'
    elif '1813' in g.loc[x,'Mocodes']:
        g.loc[x,'Suspect']='Co-worker'
    else:
        g.loc[x,'Suspect']='Others'

# %%
print(g)
# Out:
#       DATE OCC Crm Cd                                        Crm Cd Desc  \
# 35        2020    121                                     RAPE, FORCIBLE
# 271       2020    121                                     RAPE, FORCIBLE
# 425       2020    121                                     RAPE, FORCIBLE
# 578       2020    121                                     RAPE, FORCIBLE
# 599       2020    121                                     RAPE, FORCIBLE
# ...        ...    ...                                                ...
# 61682     2023    815                SEXUAL PENETRATION W/FOREIGN OBJECT
# 61744     2023    821  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...
# 61772     2023    121                                     RAPE, FORCIBLE
# 61885     2023    121                                     RAPE, FORCIBLE
# 61954     2023    820                                    ORAL COPULATION
#
#                                                  Mocodes Vict Sex  \
# 35                         1415 1402 2000 0913 1814 0527        F
# 271         0913 0537 2038 0416 0507 0527 1309 1814 2000        F
# 425                        2000 1206 2002 0913 1814 0527        F
# 578                   1814 1817 1206 1262 0527 0913 2000        F
# 599         1813 2004 1218 2060 0500 1402 1415 0913 2000        F
# ...                                                  ...      ...
# 61682                      2000 0400 0913 1814 0515 1218        F
# 61744            0913 2000 0527 0536 0537 0381 1814 0519        F
# 61772                      1206 0907 2000 0400 0416 1814        F
# 61885  2000 1820 0913 2060 1218 0448 0537 0515 2004 0381        F
# 61954                 0512 2033 2000 1814 1309 0913 0507        F
#
#       Vict Descent Premis Cd                                   Premis Desc  \
# 35               B       501                        SINGLE FAMILY DWELLING
# 271              B       502  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 425              W       502  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 578              H       108                                   PARKING LOT
# 599              O       158                          TRANSIENT ENCAMPMENT
# ...            ...       ...                                           ...
# 61682            B       101                                        STREET
# 61744            O       502  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 61772            H       502  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 61885            W       102                                      SIDEWALK
# 61954            B       101                                        STREET
#
#        DV    Suspect
# 35     No  Boyfriend
# 271    No  Boyfriend
# 425    No  Boyfriend
# 578    No  Boyfriend
# 599    No     Spouse
# ...    ..        ...
# 61682  No  Boyfriend
# 61744  No  Boyfriend
# 61772  No  Boyfriend
# 61885  No     Others
# 61954  No  Boyfriend
#
# [771 rows x 10 columns]

# %%
g7=g.groupby(['DATE OCC','Crm Cd Desc','Suspect']).size().to_frame(name="Count").reset_index()
fig = px.line(g7, x='Crm Cd Desc', y='Count', color='Suspect',animation_frame="DATE OCC", animation_group="Count",title="Rape Cases with Prime Suspects")
fig.show()
# Out:
# <div>                            <div id="2ffc207b-fcfc-4906-a162-2df3ef5deb1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ffc207b-fcfc-4906-a162-2df3ef5deb1e")) {                    Plotly.newPlot(                        "2ffc207b-fcfc-4906-a162-2df3ef5deb1e",                        [{"hovertemplate":"Suspect=Boyfriend\u003cbr\u003eDATE OCC=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[9,5,94,9,11],"legendgroup":"Boyfriend","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Boyfriend","orientation":"v","showlegend":true,"x":["ORAL COPULATION","RAPE, ATTEMPTED","RAPE, FORCIBLE","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH"],"xaxis":"x","y":[9,5,94,9,11],"yaxis":"y","type":"scatter"},{"hovertemplate":"Suspect=Others\u003cbr\u003eDATE OCC=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[4,2,27,4,5],"legendgroup":"Others","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Others","orientation":"v","showlegend":true,"x":["ORAL COPULATION","RAPE, ATTEMPTED","RAPE, FORCIBLE","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH"],"xaxis":"x","y":[4,2,27,4,5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Suspect=Spouse\u003cbr\u003eDATE OCC=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[4,4,28,8,2],"legendgroup":"Spouse","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Spouse","orientation":"v","showlegend":true,"x":["ORAL COPULATION","RAPE, ATTEMPTED","RAPE, FORCIBLE","SEXUAL PENETRATION W\u002fFOREIGN OBJECT","SODOMY\u002fSEXUAL CONTACT B\u002fW PENIS OF ONE PERS TO ANUS OTH"],"xaxis":"x","y":[4,4,28,8,2],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth": ...

# %%
g=df.loc[(df['Crm Cd']==110) | (df['Crm Cd']==113)]
g6=g.groupby(['DATE OCC','Crm Cd Desc','Vict Sex']).size().to_frame(name="Count").reset_index()
fig = px.bar(g6, x="Crm Cd Desc", y="Count", color="Vict Sex", barmode="group",facet_col="DATE OCC",title="Violent Crimes : Homicide")
fig.show()
# Out:
# <div>                            <div id="2084036c-1b2f-4358-af27-6df620e876ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2084036c-1b2f-4358-af27-6df620e876ec")) {                    Plotly.newPlot(                        "2084036c-1b2f-4358-af27-6df620e876ec",                        [{"alignmentgroup":"True","hovertemplate":"Vict Sex=F\u003cbr\u003eDATE OCC=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"textposition":"auto","x":["CRIMINAL HOMICIDE"],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=F\u003cbr\u003eDATE OCC=2021\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":false,"textposition":"auto","x":["CRIMINAL HOMICIDE"],"xaxis":"x2","y":[16],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=F\u003cbr\u003eDATE OCC=2022\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":false,"textposition":"auto","x":["CRIMINAL HOMICIDE"],"xaxis":"x3","y":[11],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=F\u003cbr\u003eDATE OCC=2023\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":false,"textposition":"auto","x":["CRIMINAL HOMICIDE"],"xaxis":"x4","y":[10],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=M\u003cbr\u003eDATE OCC=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["CRIMINAL HOMICIDE"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=M\u003cbr\u003eDATE OCC=2021\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":false,"textposition":"auto","x":["CRIMINAL HOMICIDE"],"xaxis":"x2","y":[5],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=M\u003cbr\u003eDATE OCC=2022\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":false,"textposition":"auto","x":["CRIMINAL HOMICIDE"],"xaxis":"x3","y":[7],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=M\u003cbr\u003eDATE OCC=2023\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":false,"textposition":"auto","x":["CRIMINAL HOMICIDE"],"xaxis":"x4","y":[3],"yaxis":"y4","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222222 ...

# %%
for x in g.index:
    if '1814' in g.loc[x,'Mocodes']:
        g.loc[x,'Suspect']='Boyfriend'
    elif '1813' in g.loc[x,'Mocodes']:
        g.loc[x,'Suspect']='Spouse'
    elif '1812' in g.loc[x,'Mocodes']:
        g.loc[x,'Suspect']='Foster-Parent'
    elif '1813' in g.loc[x,'Mocodes']:
        g.loc[x,'Suspect']='Co-worker'
    else:
        g.loc[x,'Suspect']='Others'

# %%
g8=g.groupby(['DATE OCC','Crm Cd Desc','Suspect']).size().to_frame(name="Count").reset_index()
fig=go.Figure(data=[go.Pie(
             values = g8['Count'],
             labels = g8['Suspect'],
             hole = 0.6,
             title='Homicide Cases with Prime Suspects')])
fig.show()
# Out:
# <div>                            <div id="37a58659-107f-4336-878d-664742a8ae2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37a58659-107f-4336-878d-664742a8ae2f")) {                    Plotly.newPlot(                        "37a58659-107f-4336-878d-664742a8ae2f",                        [{"hole":0.6,"labels":["Boyfriend","Others","Spouse","Boyfriend","Others","Spouse","Boyfriend","Others","Spouse","Boyfriend","Others","Spouse"],"title":{"text":"Homicide Cases with Prime Suspects"},"values":[2,6,4,4,12,5,4,8,6,5,7,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","siz ...
#
# var gd = document.getElementById('37a58659-107f-4336-878d-664742a8ae2f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.ge

# %%
g=df.loc[(df['Crm Cd']==235) | (df['Crm Cd']==627)]
g9=g.groupby(['DATE OCC','Crm Cd Desc','Vict Sex']).size().to_frame(name="Count").reset_index()
fig = px.bar(g9, x="Crm Cd Desc", y="Count", color="Vict Sex", barmode="group",facet_col="DATE OCC",title="Child Abuse Cases")
fig.show()
# Out:
# <div>                            <div id="ed195bbe-3bb5-4c24-82b0-1851d9ac59fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed195bbe-3bb5-4c24-82b0-1851d9ac59fb")) {                    Plotly.newPlot(                        "ed195bbe-3bb5-4c24-82b0-1851d9ac59fb",                        [{"alignmentgroup":"True","hovertemplate":"Vict Sex=F\u003cbr\u003eDATE OCC=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x","y":[2,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=F\u003cbr\u003eDATE OCC=2021\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":false,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x2","y":[1,3],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=F\u003cbr\u003eDATE OCC=2022\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":false,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x3","y":[2,4],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=F\u003cbr\u003eDATE OCC=2023\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":false,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x4","y":[2],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=M\u003cbr\u003eDATE OCC=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=M\u003cbr\u003eDATE OCC=2021\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":false,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x2","y":[1,1],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=M\u003cbr\u003eDATE OCC=2022\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":false,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x3","y":[2],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Sex=M\u003cbr\u003eDATE OCC=2023\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orien ...

# %%
g=df.loc[(df['Crm Cd']==235) | (df['Crm Cd']==627)]
g9=g.groupby(['DATE OCC','Crm Cd Desc','Vict Descent']).size().to_frame(name="Count").reset_index()
fig = px.bar(g9, x="Crm Cd Desc", y="Count", color="Vict Descent", barmode="group",facet_col="DATE OCC",labels={'DATE OCC':'Year'},title="Child Abuse Cases with respect to ethnicity")
fig.show()
# Out:
# <div>                            <div id="3c02de76-a48e-4c1b-bc32-ca986d816245" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c02de76-a48e-4c1b-bc32-ca986d816245")) {                    Plotly.newPlot(                        "3c02de76-a48e-4c1b-bc32-ca986d816245",                        [{"alignmentgroup":"True","hovertemplate":"Vict Descent=H\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"H","offsetgroup":"H","orientation":"v","showlegend":true,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x","y":[2,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Descent=H\u003cbr\u003eYear=2021\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"H","offsetgroup":"H","orientation":"v","showlegend":false,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x2","y":[1,3],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Descent=H\u003cbr\u003eYear=2022\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"H","offsetgroup":"H","orientation":"v","showlegend":false,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x3","y":[1,3],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Descent=H\u003cbr\u003eYear=2023\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"H","offsetgroup":"H","orientation":"v","showlegend":false,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x4","y":[3],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Descent=B\u003cbr\u003eYear=2020\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"B","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"v","showlegend":true,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Descent=B\u003cbr\u003eYear=2021\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"B","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"v","showlegend":false,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT"],"xaxis":"x2","y":[1],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Descent=B\u003cbr\u003eYear=2022\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"B","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"v","showlegend":false,"textposition":"auto","x":["CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT","CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT"],"xaxis":"x3","y":[1,2],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Vict Descent=W\u003cbr\u003eYear=2021\u003cbr\u003eCrm Cd Desc=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"W","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"W","offsetgroup":"W","o ...

# %%
cov = pd.read_csv("LA_County_COVID_Cases.csv")
cov['date'] = pd.to_datetime(cov['date'])

cov['month'] = cov['date'].dt.to_period('M')
d2 = cov[(cov['date'].dt.year >= 2020) & (cov['date'].dt.year <= 2023)]
monthly = d2.groupby('month')[['new_state_cases', 'new_state_deaths']].sum().reset_index()

print(monthly)
# Out:
#       month  new_state_cases  new_state_deaths
# 0   2020-03             8160               188
# 1   2020-04            43580              1997
# 2   2020-05            67097              2156
# 3   2020-06           138393              1896
# 4   2020-07           270941              3298
# 5   2020-08           200184              3995
# 6   2020-09           102593              2516
# 7   2020-10           120893              1670
# 8   2020-11           374163              1999
# 9   2020-12          1159835              7250
# 10  2021-01           892414             16100
# 11  2021-02           204635             10702
# 12  2021-03            89306              5592
# 13  2021-04            72707              2228
# 14  2021-05            44549              1199
# 15  2021-06            26792               765
# 16  2021-07           182866               970
# 17  2021-08           347690              1315
# 18  2021-09            48740               604
# 19  2021-10           -20957                 2
# 20  2021-11           141996              2303
# 21  2021-12           258423               161
# 22  2022-01           882643              2029
# 23  2022-02               26                31
# 24  2022-03                0                 0
# 25  2022-04             4787                 1
# 26  2022-05                0                 0
# 27  2022-06            63180                68
# 28  2022-07          -103519              -242
# 29  2022-08                0                 0
# 30  2022-09             1212               -68
# 31  2022-10            -1948                -8
# 32  2022-11             7065               118
# 33  2022-12         26879868            143305
# 34  2023-01         29342661            325244
# 35  2023-02         17100833            124452
# 36  2023-03          3092460             32390

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.bar(monthly['month'].astype(str), monthly['new_state_cases'], label='Cases')
plt.bar(monthly['month'].astype(str), monthly['new_state_deaths'], bottom=monthly['new_state_cases'], label='Deaths')
plt.xlabel('Month and Year')
plt.ylabel('Count')
plt.title('New COVID-19 Cases and Deaths Over Time')
plt.xticks(rotation=45)
plt.yscale('log')  # Use logarithmic scale for the y-axis
plt.legend()
plt.tight_layout()
plt.show()

# %%
dom = pd.read_csv("Domestic_Violence_Calls_from_2020_to_Present.csv")
dom['DATE OCC'] = pd.to_datetime(dom['DATE OCC'])

dom['month'] = dom['DATE OCC'].dt.to_period('M')
d2 = dom[(dom['DATE OCC'].dt.year >= 2020) & (dom['DATE OCC'].dt.year <= 2023)]
monthly = d2.groupby('month')['DATE OCC'].size().to_frame(name='Count').reset_index()
plt.figure(figsize=(12, 6))
plt.bar(monthly['month'].astype(str), monthly['Count'], label='Crime Count')
plt.xlabel('Month and Year')
plt.ylabel('Count')
plt.title('Crime Occurrences')
plt.xticks(rotation=45)
 
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #Question 1

# %% [markdown]
# One first glance covid 19 cases and crime occurrences do not have anything in common. but when compared with rape cases certain conclusions can be made.
